# %%
import pandas as pd

# %%
df = pd.read_excel("deger.ods")
df.head()
# Out:
#    Unnamed: 0                               BİRLEŞTİR  \
# 0           0                 STANDARTPARKE TAŞI 8CM
# 1           1                              DEBİMETRE
# 2           2  ELEKTROMANYETİK PİLLİ DEBİMETRE DN150
# 3           3  ELEKTROMANYETİK PİLLİ DEBİMETRE DN200
# 4           4  ELEKTROMANYETİK PİLLİ DEBİMETRE DN250
#
#                                                AMBAR  \
# 0  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 1  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 2  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 3  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 4  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
#
#                                  MALZEME ÖLÇÜ  MİKTAR  deger  Unnamed: 7  \
# 0                 STANDARTPARKE TAŞI 8CM    0    80.0    8.0         NaN
# 1                              DEBİMETRE    0     2.0    NaN         NaN
# 2  ELEKTROMANYETİK PİLLİ DEBİMETRE DN150    0     1.0  150.0         NaN
# ...

# %%
df[df["MİKTAR"] == 80]
# Out:
#      Unnamed: 0                BİRLEŞTİR  \
# 0             0  STANDARTPARKE TAŞI 8CM
# 209         209    PPRC REDÜKSİYON 40/25
#
#                                                  AMBAR  \
# 0    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 209  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
#
#                     MALZEME   ÖLÇÜ  MİKTAR  deger  Unnamed: 7  Unnamed: 8
# 0    STANDARTPARKE TAŞI 8CM      0    80.0    8.0         NaN         NaN
# 209         PPRC REDÜKSİYON  40/25    80.0    NaN         NaN         NaN

# %%
df[df["MİKTAR"] == 1]
# Out:
#      Unnamed: 0                                        BİRLEŞTİR  \
# 2             2           ELEKTROMANYETİK PİLLİ DEBİMETRE DN150
# 3             3           ELEKTROMANYETİK PİLLİ DEBİMETRE DN200
# 19           19                                F.D.DIRSEK 45 150
# 21           21                             F.D.DIRSEK 11.25 150
# 22           22                           F.D.REDIKSIYON 150/100
# 35           35                              F.D.DIRSEK 22.5 200
# 105         105  ÇİFT KÜRESELLİ VANA PRİZ KOLYE SETİ DN150XQ40MM
# 131         131      ATLAS UZAKTAN OKUMALI SOĞUK SU SAYACI DN200
# 135         135                         BASINC DUSURUCU VANA 100
# 136         136                         BASINC DUSURUCU VANA 150
# 223         223           PPRC DIŞ DİŞLİ OYNAR BAŞLI REKOR 32*32
#
#                                                  AMBAR  \
# 2    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 3    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# ...

# %%
filtre1 = df["MİKTAR"] > 80 
filtre2 = df["deger"] < 100

df[filtre1 & filtre2]
# Out:
#      Unnamed: 0                                  BİRLEŞTİR  \
# 55           55                ENTEGRE BETON BORU 1,50 300
# 61           61         60 MM BACA YÜKSELTME HALKASI 6 CM
# 90           90                    KOLAY TAMİR PARÇASI 32
# 91           91                    KOLAY TAMİR PARÇASI 40
# 121         121                       BAYLAN BW50 R-160 50
# 125         125  BAYLAN SOĞUK SU SAYACI 25 MM R-160 TK-3C
# 126         126        BAYLAN SOĞUK SU SAYACI 40 MM TK-5C
# 206         206                            MANŞON PPRC 50
# 214         214                          PPRC DİRSEK 90 32
# 215         215                          PPRC DİRSEK 90 40
#
#                                                  AMBAR  \
# 55   ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 61   ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 90   ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 91   ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# ...

# %%
df[df["MİKTAR"].between(50,100)]
# Out:
#      Unnamed: 0                           BİRLEŞTİR  \
# 0             0             STANDARTPARKE TAŞI 8CM
# 9             9                 F.D.DIRSEK 22,5 100
# 56           56  ENTEGRE CONTALI BETON BORU1,25 400
# 79           79             KOLAY TAMİR PARÇASI 100
# 209         209               PPRC REDÜKSİYON 40/25
# 213         213                   PPRC DİRSEK 90 25
# 224         224          PPRC DIŞ DİŞLİ REKOR 20*20
# 226         226       PPRC İÇ DİŞLİ REKOR Q 50-1/2"
# 231         231          PPRC DIŞ DİŞLİ REKOR 50 MM
# 250         250   SU TASARRUF APARATLI MİKS MUSLUK
#
#                                                  AMBAR  \
# 0    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 9    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 56   ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 79   ABONE İŞLERİ 1. BÖLGE DAİRESİ BAŞKANLIĞI SARF ...
# 209  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# 213  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI FERHA...
# ...

# %%
df["AMBAR"] = df["AMBAR"].str.lower()
df
# Out:
#      Unnamed: 0                               BİRLEŞTİR  \
# 0             0                 STANDARTPARKE TAŞI 8CM
# 1             1                              DEBİMETRE
# 2             2  ELEKTROMANYETİK PİLLİ DEBİMETRE DN150
# 3             3  ELEKTROMANYETİK PİLLİ DEBİMETRE DN200
# 4             4  ELEKTROMANYETİK PİLLİ DEBİMETRE DN250
# ..          ...                                     ...
# 246         246                      YAGLI SALMASTRA 10
# 247         247                      YAGLI SALMASTRA 12
# 248         248                       PPRC KÖRTAPA 3/4"
# 249         249                       ÇERÇEVELİ PORTRE
# 250         250       SU TASARRUF APARATLI MİKS MUSLUK
#
#                                                  AMBAR  \
# 0    abone i̇şleri̇ 3. bölge dai̇resi̇ başkanliği f...
# 1    abone i̇şleri̇ 3. bölge dai̇resi̇ başkanliği f...
# 2    abone i̇şleri̇ 3. bölge dai̇resi̇ başkanliği f...
# 3    abone i̇şleri̇ 3. bölge dai̇resi̇ başkanliği f...
# ...

# %%
df[df["AMBAR"].str.contains("2. bölge")]
# Out:
#      Unnamed: 0                                        BİRLEŞTİR  \
# 13           13                                   F.D.DIRSEK 100
# 51           51                               PUSFİT DİRSEK 1X40
# 52           52                                 PUSHFİT 1.1/4X40
# 80           80                          KOLAY TAMİR PARÇASI 100
# 86           86                          KOLAY TAMİR PARÇASI 300
# 104         104  ÇİFT KÜRESELLİ VANA PRİZ KOLYE SETİ DN150XQ40MM
# 116         116                                  BAYLAN SAYAÇ 20
# 117         117            BAYLAN SAYAÇ NB -IOT SU SAYACI DN20MM
# 118         118            BAYLAN SAYAÇ LORAWAN SU SAYACI DN20MM
# 119         119    BAYLAN EĞİK KADRANLI SOĞUK SU SAYACI DN 20 MM
# 120         120                                  BAYLAN SAYAÇ 50
# 121         121                             BAYLAN BW50 R-160 50
# 122         122                             BAYLAN BW80 R-160 80
# ...

# %%
df
# Out:
#      Unnamed: 0                               BİRLEŞTİR  \
# 0             0                 STANDARTPARKE TAŞI 8CM
# 1             1                              DEBİMETRE
# 2             2  ELEKTROMANYETİK PİLLİ DEBİMETRE DN150
# 3             3  ELEKTROMANYETİK PİLLİ DEBİMETRE DN200
# 4             4  ELEKTROMANYETİK PİLLİ DEBİMETRE DN250
# ..          ...                                     ...
# 246         246                      YAGLI SALMASTRA 10
# 247         247                      YAGLI SALMASTRA 12
# 248         248                       PPRC KÖRTAPA 3/4"
# 249         249                       ÇERÇEVELİ PORTRE
# 250         250       SU TASARRUF APARATLI MİKS MUSLUK
#
#                                                  AMBAR  \
# 0    abone i̇şleri̇ 3. bölge dai̇resi̇ başkanliği f...
# 1    abone i̇şleri̇ 3. bölge dai̇resi̇ başkanliği f...
# 2    abone i̇şleri̇ 3. bölge dai̇resi̇ başkanliği f...
# 3    abone i̇şleri̇ 3. bölge dai̇resi̇ başkanliği f...
# ...

# %%
df["AMBAR"] = df["AMBAR"].str.upper()
df
# Out:
#      Unnamed: 0                               BİRLEŞTİR  \
# 0             0                 STANDARTPARKE TAŞI 8CM
# 1             1                              DEBİMETRE
# 2             2  ELEKTROMANYETİK PİLLİ DEBİMETRE DN150
# 3             3  ELEKTROMANYETİK PİLLİ DEBİMETRE DN200
# 4             4  ELEKTROMANYETİK PİLLİ DEBİMETRE DN250
# ..          ...                                     ...
# 246         246                      YAGLI SALMASTRA 10
# 247         247                      YAGLI SALMASTRA 12
# 248         248                       PPRC KÖRTAPA 3/4"
# 249         249                       ÇERÇEVELİ PORTRE
# 250         250       SU TASARRUF APARATLI MİKS MUSLUK
#
#                                                  AMBAR  \
# 0    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI F...
# 1    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI F...
# 2    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI F...
# 3    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI F...
# ...

# %%
df[df["MALZEME"].str.startswith("E")]
# Out:
#     Unnamed: 0                                        BİRLEŞTİR  \
# 2            2           ELEKTROMANYETİK PİLLİ DEBİMETRE DN150
# 3            3           ELEKTROMANYETİK PİLLİ DEBİMETRE DN200
# 4            4           ELEKTROMANYETİK PİLLİ DEBİMETRE DN250
# 5            5           ELEKTROMANYETİK PİLLİ DEBİMETRE DN300
# 6            6                       ELEKTRONİK BKV KONTROLÖRÜ
# 7            7           ELEKTROMANYETİK PİLLİ DEBİMETRE DN100
# 55          55                      ENTEGRE BETON BORU 1,50 300
# 56          56               ENTEGRE CONTALI BETON BORU1,25 400
# 57          57                ENTG. CONT. BACA ÇEMBERİ 1000/600
# 58          58                  ENT. CONT. BACA ÇEMBERİ 100/300
# 59          59             ENTEGRE CONTALI BACA ÇEMBERİ 625/600
# 60          60         ENTEG.CONT.BETONARME BACA ÇEMBERİ 625/30
# 63          63    ENTG.CONT.PREKAST BACA TABAN ELM.İKİLİ 300 MM
# 64          64  ENTG.CONT.PREKAST BACA TABAN ELEMANI İKİ 400 MM
# ...

# %%
df[df["MALZEME"].str.endswith("Ü")]
# Out:
#      Unnamed: 0                        BİRLEŞTİR  \
# 6             6       ELEKTRONİK BKV KONTROLÖRÜ
# 138         138          BASINÇ DÜŞÜRÜCÜ 1 1/4''
# 239         239  KELEBEK MÜHÜR PASLANMAZ BÜKÜLÜ
#
#                                                  AMBAR  \
# 6    ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI F...
# 138  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI F...
# 239  ABONE İŞLERİ 3. BÖLGE DAİRESİ BAŞKANLIĞI F...
#
#                             MALZEME     ÖLÇÜ  MİKTAR  deger  Unnamed: 7  \
# 6         ELEKTRONİK BKV KONTROLÖRÜ        0     3.0    NaN         NaN
# 138                 BASINÇ DÜŞÜRÜCÜ  1 1/4''   270.0    NaN         NaN
# 239  KELEBEK MÜHÜR PASLANMAZ BÜKÜLÜ        0  5400.0    NaN         NaN
#
#      Unnamed: 8
# 6           NaN
# 138         NaN
# 239         NaN
